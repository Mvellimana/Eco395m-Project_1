# %%
import requests as r
import pandas as pd
from itertools import product
import csv

# %%
url = 'https://api.yelp.com/v3/businesses/search'
key = 'Sol4vIOXEW3F6vyEqyOOK9GvZXRj0uNAMwuBVQXMp7zFLJ-XJGXAs8vMcTh0oCjai0qqfAdis6WzkqfQr9RXDrq3PvNwGvS4T7RSbVLWxcmYzTqa9GR7OXt_xv5CY3Yx'
headers = {
    'Authorization': 'Bearer %s' % key,
}

# %%
url_params = {"location" : "Austin, TX",
                "limit" : 50,
                "term" : "restaurants",
                "radius" : 2400,
                "offset" : 0,
                "locale" : "en_US"}

response = r.request('GET', url, headers=headers, params=url_params)
    
print(response.json())
# Out:
# {'businesses': [{'id': '-H_cbWJ6Wqe5lxRm4l7h_w', 'alias': 'spread-and-co-austin', 'name': 'Spread & Co', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AO60W1yjPk9EFxZKcQeJqQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/spread-and-co-austin?adjust_creative=tZZljcWm7SeCMXc1cy9laA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tZZljcWm7SeCMXc1cy9laA', 'review_count': 107, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}], 'rating': 4.5, 'coordinates': {'latitude': 30.3086982, 'longitude': -97.7504555}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '1601 W 38th St', 'address2': 'Ste 1', 'address3': '', 'city': 'Austin', 'zip_code': '78731', 'country': 'US', 'state': 'TX', 'display_address': ['1601 W 38th St', 'Ste 1', 'Austin, TX 78731']}, 'phone': '+15128142002', 'display_phone': '(512) 814-2002', 'distance': 800.9835230353954}, {'id': '6Gxs1T1lJJ1PlMWZIcEw_g', 'alias': 'oakmont-food-austin-6', 'name': 'Oakmont Food', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/B4LgzaQYC_nBdJEXdSDX5g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/oakmont-food-austin-6?adjust_creative=tZZljcWm7SeCMXc1cy9laA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tZZljcWm7SeCMXc1cy9laA', 'review_count': 202, 'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 30.306147, 'longitude': -97.744355}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '1106 W 38th St', 'address2': '', 'address3': None, 'city': 'Austin', 'zip_code': '78705', 'country': 'US', 'state': 'TX', 'display_address': ['1106 W 38th St', 'Austin, TX 78705']}, 'phone': '+15124336011', 'display_phone': '(512) 433-6011', 'distance': 1287.8451143152483}, {'id': '1NpVlW3O_vWQQy6cxLFhtA', 'alias': 'food-food-austin', 'name': 'Food Food', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tPj2ILHXSY8kf-fZc5MnqA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/food-food-austin?adjust_creative=tZZljcWm7SeCMXc1cy9laA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tZZljcWm7SeCMXc1cy9laA', 'review_count': 90, 'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'cupcakes', 'title': 'Cupcakes'}], 'rating': 4.0, 'coordinates': {'latitude': 30.303975, 'longitude': -97.763838}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '2727 Exposition Blvd', 'address2': 'Ste 112', 'address3': '', 'city': 'Austin', 'zip_code': '78703', 'country': 'US', 'state': 'TX', 'display_address': ['2727 Exposition Blvd', 'Ste 112', 'Austin, TX 78703']}, 'phone': '+15124748515', 'display_phone': '(512) 474-8515', 'distance': 601.7527130995852}, {'id': 'KJuHFlqhapJb8tVWCe8MNg', 'alias': 'rosedale-kitchen-and-bar-austin', 'name': 'Rosedale Kitchen and Bar', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_Bf0qkQioSFVAEM08KW0-w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/rosedale-kitchen-and-bar-austin?adjust_creative=tZZljcWm7SeCMXc1cy9laA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tZZljcWm7SeCMXc1cy9laA', 'review_count': 164, 'categories': [{'alias': 'newamerican', 'title': 'American (New)'}], 'rating': 4.0, 'coordinates': {'latitude': 30.306, 'longitude': -97.74302}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '3800 N Lamar Blvd', 'address2': '', 'address3': '', 'city': 'Austin', 'zip_code': '78756', 'country': 'US', 'state': 'TX', 'display_address': ['3800 N Lamar Blvd', 'Austin, TX 78756']}, 'phone': '+15127290052', 'display_phone': '(512) 729-0052', 'distance': 1400.7586567911671}, {'id': 'cIbVQrylwj3Rljpka5AZ9w', 'alias': 'olive-and-june-austin-2' ...

# %%
restaurants_list = []
