# %%
import requests as r
import pandas as pd
from itertools import product
import csv
import operator

# %%
url = 'https://api.yelp.com/v3/businesses/search'
key = 'Sol4vIOXEW3F6vyEqyOOK9GvZXRj0uNAMwuBVQXMp7zFLJ-XJGXAs8vMcTh0oCjai0qqfAdis6WzkqfQr9RXDrq3PvNwGvS4T7RSbVLWxcmYzTqa9GR7OXt_xv5CY3Yx'
headers = {
    'Authorization': 'Bearer %s' % key,
}

# %%
url_params = {"location" : "Austin, TX",
                "limit" : 50,
                "term" : "restaurants",
                "offset" : 0,
                "locale" : "en_US"}

response = r.request('GET', url, headers=headers, params=url_params)
    
print(response.json())
# Out:
# {'businesses': [{'id': 'AcFt364BrHyMu3VrSCKMOw', 'alias': 'salty-sow-austin', 'name': 'Salty Sow', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9L94UUzP7_maYsOWjxhZJg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/salty-sow-austin?adjust_creative=tZZljcWm7SeCMXc1cy9laA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tZZljcWm7SeCMXc1cy9laA', 'review_count': 3036, 'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'gastropubs', 'title': 'Gastropubs'}], 'rating': 4.5, 'coordinates': {'latitude': 30.2836497259461, 'longitude': -97.7213180065155}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '1917 Manor Rd', 'address2': '', 'address3': '', 'city': 'Austin', 'zip_code': '78722', 'country': 'US', 'state': 'TX', 'display_address': ['1917 Manor Rd', 'Austin, TX 78722']}, 'phone': '+15123912337', 'display_phone': '(512) 391-2337', 'distance': 4234.901451292925}, {'id': 'cs6HfZNykLVitm09jWFqWg', 'alias': 'moonshine-patio-bar-and-grill-austin', 'name': 'Moonshine Patio Bar & Grill', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wpnO7yB337a5rnhcZVJAiA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/moonshine-patio-bar-and-grill-austin?adjust_creative=tZZljcWm7SeCMXc1cy9laA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tZZljcWm7SeCMXc1cy9laA', 'review_count': 5464, 'categories': [{'alias': 'southern', 'title': 'Southern'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}], 'rating': 4.5, 'coordinates': {'latitude': 30.263769, 'longitude': -97.738036}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '303 Red River St', 'address2': '', 'address3': '', 'city': 'Austin', 'zip_code': '78701', 'country': 'US', 'state': 'TX', 'display_address': ['303 Red River St', 'Austin, TX 78701']}, 'phone': '+15122369599', 'display_phone': '(512) 236-9599', 'distance': 4975.0969571515425}, {'id': 'fTpp8kuKOITj1KSEz9UG2Q', 'alias': 'qi-austin-austin-2', 'name': 'Qi Austin', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PjiyGaMn4vhIYKQzEcUbTA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/qi-austin-austin-2?adjust_creative=tZZljcWm7SeCMXc1cy9laA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tZZljcWm7SeCMXc1cy9laA', 'review_count': 392, 'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}], 'rating': 4.5, 'coordinates': {'latitude': 30.27068524160311, 'longitude': -97.75237547576404}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '835 W 6th St', 'address2': 'Ste 114', 'address3': None, 'city': 'Austin', 'zip_code': '78703', 'country': 'US', 'state': 'TX', 'display_address': ['835 W 6th St', 'Ste 114', 'Austin, TX 78703']}, 'phone': '+15124742777', 'display_phone': '(512) 474-2777', 'distance': 3867.215233366278}, {'id': 'GwAFL29gpnEIjAG9MauMig', 'alias': 'aba-austin-austin', 'name': 'Aba - Austin', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9T_T51yqsssMnCvyExsChQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/aba-austin-austin?adjust_creative=tZZljcWm7SeCMXc1cy9laA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=tZZljcWm7SeCMXc1cy9laA', 'review_count': 809, 'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'seafood', 'title': 'Seafood'}], 'rating': 4.5, 'coordinates': {'latitude': 30.253507773542832, 'longitude': -97.7478877}, 'transactions': ['pickup', 'delivery'], 'location': {'address1': '1011 S Congress Ave', 'address2': 'Bldg 2, Ste 180', 'address3': None, 'city': 'Austin', 'zip_code': '78704', 'country': 'US', 'state': 'TX', 'display_address': ['1011 S Congress Ave', 'Bldg 2, Ste 180', 'Austin, TX 78704']}, 'phone': '+17372730199', 'display_phone': '(737) 273-0199', 'distance': 5820.155353424085}, {'id': 'Rba9Ol4jnTiov6_iAuoF5g', 'alias': '1618-asian-fusion-austin', 'name': '1618 Asian Fusion', 'image_u ...

# %%
restaurants_list = []

# %%
request = r.get(url, headers = headers, params = url_params)
for business in response.json()["businesses"]:
    id = business["id"]
    name = business["name"]
    rating = business["rating"]
    #price = business["price"]
    restaurants_list.append([id,name,rating])

# %%
restaurants = []

# %%
for i in range(len(restaurants_list)):
        info = {
        "id": restaurants_list[i][0],
        "name": restaurants_list[i][1],
        "rating": restaurants_list[i][2]
        }

        restaurants.append(info)

# %%
restaurants_sorted = sorted(restaurants, key = operator.itemgetter("id"), reverse=True)

#print(restaurants_sorted)
# Out:
# [{'id': 'yqL1P6wcSZYQAgpO3TfhBQ', 'name': 'Kemuri Tatsu-ya', 'rating': 4.0}, {'id': 'x_tD_UygC_nN23QJpni7ww', 'name': 'Hold Out Brewing', 'rating': 4.5}, {'id': 'wB1qckz9iC0aq5XuWRmCIA', 'name': 'Jewboy Burgers', 'rating': 4.5}, {'id': 'v1UzkU8lEWdjxq8byWFOKg', 'name': "Gus's World Famous Fried Chicken", 'rating': 4.5}, {'id': 'uPWJtYJi76EniU0xrX-zbA', 'name': 'Odd Duck', 'rating': 4.5}, {'id': 'shFV63u-qAkHNfz3ZG4sIw', 'name': 'Tumble 22', 'rating': 4.0}, {'id': 's1BZDYxBS_rYOiIHAYHQhA', 'name': 'Tukka', 'rating': 4.5}, {'id': 'nXtn29mTWlYeHxvHSz4dfA', 'name': 'Koriente', 'rating': 4.5}, {'id': 'mDhPwgvxpI_Ny-NIn4M76A', 'name': 'Provision Dining House', 'rating': 4.0}, {'id': 'iuy7Wk41ZlSzk2DhNv0ymQ', 'name': 'TenTen', 'rating': 4.5}, {'id': 'fTpp8kuKOITj1KSEz9UG2Q', 'name': 'Qi Austin', 'rating': 4.5}, {'id': 'fDKbXHlYKZsI02j6_qBSAA', 'name': 'Austin Rotisserie', 'rating': 4.5}, {'id': 'cs6HfZNykLVitm09jWFqWg', 'name': 'Moonshine Patio Bar & Grill', 'rating': 4.5}, {'id': 'cTwsI0U1x1xeOrCdgIaJ2w', 'name': 'Acre 41', 'rating': 4.0}, {'id': 'c-IkQb9dVRoQNW1KKP--mA', 'name': 'Smash ATX', 'rating': 4.5}, {'id': 'bxy_v6jkfCiVYhvn4t8T7Q', 'name': 'Vamonos', 'rating': 4.5}, {'id': '_ApCaOQWaAwVGTlIKRpZng', 'name': 'DipDipDip Tatsu-Ya', 'rating': 4.0}, {'id': 'XOo0oa5sXCZGjKXapIN95w', 'name': 'Red Ash', 'rating': 4.5}, {'id': 'Unl62KlI0kwF8pToy7QjSA', 'name': "Vic & Al's", 'rating': 5.0}, {'id': 'Rba9Ol4jnTiov6_iAuoF5g', 'name': '1618 Asian Fusion', 'rating': 4.5}, {'id': 'QmGqhWkdued9L98MP-jiPg', 'name': 'Thrive Craft House', 'rating': 4.5}, {'id': 'QjBJ4-iH3MUoPGXQqa9X2Q', 'name': "Irene's", 'rating': 4.0}, {'id': 'PrWSjn4a8o4dHoqKs53GBA', 'name': 'Bird Bird Biscuit', 'rating': 4.5}, {'id': 'P2fi7qugfLPOFSxscpaAxg', 'name': 'Anthem', 'rating': 4.5}, {'id': 'NaRmhh_q5X3NNcrHK4HKRQ', 'name': 'Picnik Burnet Road', 'rating': 4.0}, {'id': 'LoSheJfJ57sNedZj0GWO5A', 'name': 'Bar Peached', 'rating': 4.5}, {'id': 'LNJIUbU6bKOYBreQGGd0Rg', 'name': "Uncle Nicky's", 'rating': 4.5}, {'id': 'KJuHFlqhapJb8tVWCe8MNg', 'name': 'Rosedale Kitchen and Bar', 'rating': 4.0}, {'id': 'KIHoGUfCOLhBFQVSAN4QSg', 'name': 'Suerte', 'rating': 4.5}, {'id': 'JW3SkLOUfGhcVQGosoozUA', 'name': 'Launderette', 'rating': 4.0}, {'id': 'INUWOG0fuuYwinCEA2BrHQ', 'name': "Phoebe's Diner", 'rating': 4.5}, {'id': 'He2KYtXXfaIR0nkCXH5xiQ', 'name': 'Loro', 'rating': 4.0}, {'id': 'HKi7fd2bTzZfVB_Dz9vGng', 'name': 'Lucky Robot', 'rating': 4.0}, {'id': 'H6TRTjlEy1_GWlcOuZzbHA', 'name': 'Birria Queen ', 'rating': 5.0}, {'id': 'GwAFL29gpnEIjAG9MauMig', 'name': 'Aba - Austin', 'rating': 4.5}, {'id': 'EaHJ9kb6XTIQqddyAFdf-Q', 'name': 'Gather & Forge', 'rating': 5.0}, {'id': 'EQZj0LWbjBpnRnLicE_xbA', 'name': 'Este', 'rating': 5.0}, {'id': 'DzrgzDDKSpACYWW3yKSt7A', 'name': 'Oseyo', 'rating': 4.0}, {'id': 'Cipqsy7Fdnt9IiglUxx2NQ', 'name': 'Jjim Korean Braised BBQ', 'rating': 4.5}, {'id': 'Bz-NZ-2Dx6pztO0nvfD3JA', 'name': 'Nori', 'rating': 4.5}, {'id': 'BcnoKR1af6HBjp065HjlHg', 'name': 'Epicerie At The Contemporary', 'rating': 5.0}, {'id': 'AsYbCd5d7TtIZEWIL5VhOw', 'name': 'Roaring Fork', 'rating': 4.0}, {'id': 'AcFt364BrHyMu3VrSCKMOw', 'name': 'Salty Sow', 'rating': 4.5}, {'id': '8fNk1tcxZpkVAs1_hqebLA', 'name': 'Higher Ground', 'rating': 4.5}, {'id': '6e3UQmbqFLGWWDCI5VczCA', 'name': 'Hopfields', 'rating': 4.0}, {'id': '6Gxs1T1lJJ1PlMWZIcEw_g', 'name': 'Oakmont Food', 'rating': 4.0}, {'id': '5ufHVEdJNPypB4v_UhUUUQ', 'name': "Patrizi's", 'rating': 4.5}, {'id': '4h-O6wPWswMbVowT_lYn9g', 'name': 'Tiki Tatsu-Ya', 'rating': 4.0}, {'id': '3AGDyk6AdnCAxY8Am2XqAw', 'name': 'Golden Tiger', 'rating': 4.0}, {'id': '-pZltwxs2RBzQFFcb-O55A', 'name': 'Old Thousand II - "Dope Chinese"', 'rating': 4.0}]

# %%
with open("results.csv", "w", encoding = "utf-8", newline="") as output_file:
     dict_writer = csv.DictWriter(output_file, fieldnames=["id", "name", "rating"])
     dict_writer.writeheader()
     dict2 = dict_writer.writerows(restaurants_sorted)
